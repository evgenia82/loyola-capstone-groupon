# %% [markdown]
# #### 1.1 Load the data.

# %%
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
from matplotlib.dates import MonthLocator, DateFormatter
# %matplotlib inline
import numpy as np
import pandas as pd
from datetime import datetime
import seaborn as sns
sns.set_style('whitegrid')
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
import warnings
warnings.filterwarnings("ignore")
import sklearn.linear_model as sk_linear
import sklearn.ensemble as sk_ens

# %%
#df = pd.read_csv('groupon.txt', sep=None, engine='python')
#df.to_parquet('groupon.parquet')

# %%
df = pd.read_parquet('groupon.parquet')

# %%
df.head()
# Out:
#             refund_bucket refund_sub_bucket order_date transaction_date  \
# 0                   Other             Other   8/4/2016         8/4/2016
# 1                 Returns    Change of mind  8/31/2018        9/21/2018
# 2                   Fraud             Fraud  4/19/2017        4/19/2017
# 3        Two-Hour Refunds  Two-Hour Refunds   2/5/2016         2/5/2016
# 4  Shortage Cancellations   Vendor Shortage  7/21/2018        8/15/2018
#
#   week_end_date                    dmm_subcat_1                   category_1  \
# 0      8/7/2016                  Inverse Normal  Probability distribution II
# 1     9/23/2018          Binomial Distribution.   Probability distribution I
# 2     4/23/2017                    Power series                  Calculus II
# 3      2/7/2016  Prime Factorization Algorithms                            ?
# 4     8/19/2018                 Transformations                     Geometry
#
#   deal_supply_channel buyer_name_1 auth_bookings capture_bookings  \
# 0        Goods Stores       Asher              ?                ?
# 1               Goods       Jesus              ?                ?
# 2               Goods     Tristan              ?                ?
# 3               Goods    Jeremiah              ?                ?
# 4               Goods       Jacob              ?                ?
#
#         refunds cancel_refunds refunded_units auth_refunds capture_units
# 0         91.87              ?              3            ?             ?
# 1         20.98              ?              1            ?             ?
# 2             ?          79.94              ?            ?             ?
# 3  49.267469958              ?              1            ?             ?
# 4         29.97              ?              2            ?             ?

# %% [markdown]
# Our dataframe consists of 16 columns and approximately 6.8 millions rows. The dataframe is huge as it occupies almost 1 GB of memory. Python loaded all columns as objects - so we need to transform data into right data type. The original dictionary with data types description is provided below.
#
# |Column_name	                |Type		|Description
# | --- | --- | --- |
# |refund_bucket                 	|Varchar	|Reason for refunding customer
# |refund_sub_bucket             	|Varchar	|Sub reason for refunding customer
# |transaction_date              	|Date		|date of refund
# |week_end_date                 	|Date		|weekend date of refund
# |dmm_subcat                    	|Varchar	|sub category of product
# |category                      	|Varchar	|category of product
# |deal_supply_channel           	|Varchar	|channel of sale
# |buyer_name                    	|Varchar	|name of buyer who sourced the product
# |auth_bookings                 	|Float		|bookings authorized on card
# |capture_bookings              	|Float		|bookings captured
# |refunds                       	|Float		|amount of refund
# |cancel_refunds                	|Float		|refunds if the transaction was a cancellation
# |refunded_units                	|Integer	|quantity of product for which refunds were issued
# |auth_refunds                  	|Integer	|
# |capture_units                 	|Integer	|

# %% [markdown]
# To allow a faster processing and easy data manipulation let's subset our dataframe to separate one year of transactions and refunds based on a transaction date. I will take 2018 data.
#
# To do so I need to convert all date's columns to Python date-time format and will use a boolean mask to create a subset.

# %%
df['order_date'] = pd.to_datetime(df['order_date'], infer_datetime_format=True)
df['transaction_date'] = pd.to_datetime(df['transaction_date'], infer_datetime_format=True)
df['week_end_date'] = pd.to_datetime(df['week_end_date'], infer_datetime_format=True)

# %% [markdown]
# Since I have already converted date's columns to date format, I can set a desired date to filter a dataframe. Then I will assign a mask to dateaframe.

# %%
start_date = '2018-01-01'
end_date = '2018-12-31'
mask = (df['transaction_date'] >= start_date) & (df['transaction_date'] <= end_date)
subset = df.loc[mask]
subset.shape
# Out:
# (2162199, 16)

# %%
subset = subset.copy()

# %%
subset.columns
# Out:
# Index(['refund_bucket', 'refund_sub_bucket', 'order_date', 'transaction_date',
#        'week_end_date', 'dmm_subcat_1', 'category_1', 'deal_supply_channel',
#        'buyer_name_1', 'auth_bookings', 'capture_bookings', 'refunds',
#        'cancel_refunds', 'refunded_units', 'auth_refunds', 'capture_units'],
#       dtype='object')

# %%
subset.drop(['refund_bucket', 'refund_sub_bucket', 'order_date', 'week_end_date', 
             'dmm_subcat_1', 'category_1', 'deal_supply_channel','buyer_name_1', 
             'auth_bookings','cancel_refunds', 'refunded_units', 'auth_refunds', 
             'capture_units'], axis = 1, inplace = True)

# %% [markdown]
# Now let's convert capture_bookings into the float data type.

# %%
subset['capture_bookings'] = subset['capture_bookings'].str.replace('?', '0').astype(float)
subset['refunds'] = subset['refunds'].str.replace('?', '0').astype(float)

# %% [markdown]
# Let's create year, month, and day columns to plot refund and transaction amounts

# %%
variable = pd.DatetimeIndex(subset['transaction_date'])
subset['year'],subset['month'],subset['day'] = variable.year, variable.month, variable.day

# %%
avg_data = subset.groupby(['month','day']).agg({'refunds':np.mean,'capture_bookings':np.mean})
avg_data.index = [datetime(2018,month,day) for (month, day) in avg_data.index]

# %%
plt.figure()
plt.figure(figsize=(18,6))

# subplot 1
plt.subplot(1,2,1)
avg_data['refunds'].plot(colormap='seismic',alpha=0.4)
plt.text('2018-12-25',62,'Christmas',ha='center')
plt.text('2018-01-01',63.5,"New Year's Day",ha='center')
plt.text('2018-02-14',50,"Valentine's Day",ha='center')
plt.ylabel('Average refund amount, $')
plt.title(r'Groupon Average Refund Amount')
plt.margins(0.010, 0.025)

# subplot 2
plt.subplot(1,2,2)
avg_data['capture_bookings'].plot(colormap='autumn', alpha=0.4)
plt.text('2018-11-23',2675,'Thanksgiving',ha='center')
plt.ylabel('Average transaction amount, $')
plt.title(r'Groupon Average Transaction Amount')
plt.margins(0.010, 0.025)
plt.show()

# %% [markdown]
# From the following plots, we can clearly see that refunds and transactions have spikes and valleys. A clear seasnal trend can be detected here. We can observe the biggest transaction spike during Thanksgiving, when most people shop for Christmas gifts. We can also observe the highest amount of refunds during Christmas, New Year's, and Valentine's Day, when people return gifts they didn't like.

# %%
refunds_df = df[['transaction_date', 'refunds']]
refunds_df['refunds'] = refunds_df['refunds'].str.replace('?', '0').astype(float)
refunds_df = refunds_df.resample('D', on='transaction_date').mean()
print(refunds_df.shape)
refunds_df.head()
# Out:
# (1186, 1)
#                   refunds
# transaction_date
# 2016-01-01          86.29
# 2016-01-02          83.79
# 2016-01-03          72.15
# 2016-01-04          67.73
# 2016-01-05          82.10

# %% [markdown]
# ### Build Foundation for Time Series Forecasting
#
# I referenced the following Medium article while expoling Groupon data. [A Tutorial on Time Series EDA and Data Preparation using Python](https://towardsdatascience.com/time-series-forecasting-968192b3781a)

# %%
#Summary statistics of the data
print(refunds_df.describe())
# Out:
#        refunds
# count  1186.00
# mean     52.79
# std      21.39
# min      10.06
# 25%      35.38
# 50%      56.24
# 75%      69.13
# max     154.99

# %%
# create a lag feature

dataframe = pd.concat([refunds_df.refunds.shift(1), refunds_df.refunds], axis=1)
dataframe.columns = ['t', 't+1']
dataframe.reset_index(inplace = True)
dataframe.drop(['transaction_date'], inplace = True, axis = 1)
dataframe.head()
# Out:
#       t   t+1
# 0   nan 86.29
# 1 86.29 83.79
# 2 83.79 72.15
# 3 72.15 67.73
# 4 67.73 82.10

# %%
# create multiple lag features

dataframe = pd.concat([refunds_df.refunds.shift(3), refunds_df.refunds.shift(2), refunds_df.refunds.shift(1), 
                       refunds_df.refunds], axis=1)
dataframe.columns = ['t-2', 't-1', 't', 't+1']
dataframe.reset_index(inplace = True)
dataframe.drop(['transaction_date'], inplace = True, axis = 1)
print(dataframe.head(5))
# Out:
#     t-2   t-1     t   t+1
# 0   nan   nan   nan 86.29
# 1   nan   nan 86.29 83.79
# 2   nan 86.29 83.79 72.15
# 3 86.29 83.79 72.15 67.73
# 4 83.79 72.15 67.73 82.10

# %%
# create a rolling mean feature for few lag observations

shifted = refunds_df.refunds.shift(1)
window = shifted.rolling(window=2)
means = window.mean()
dataframe = pd.concat([means, refunds_df.refunds], axis=1)
dataframe.columns = ['mean(t-1,t)', 't+1']
dataframe.reset_index(inplace = True)
dataframe.drop(['transaction_date'], inplace = True, axis = 1)
print(dataframe.head(5))
# Out:
#    mean(t-1,t)   t+1
# 0          nan 86.29
# 1          nan 83.79
# 2        85.04 72.15
# 3        77.97 67.73
# 4        69.94 82.10

# %%
# create expanding window features for all lag observations

window = refunds_df.refunds.expanding()
dataframe = pd.concat([window.min(), window.mean(), window.max(), refunds_df.refunds.shift(-1)], axis=1)
dataframe.columns = ['min', 'mean', 'max', 't+1']
dataframe.reset_index(inplace = True)
dataframe.drop(['transaction_date'], inplace = True, axis = 1)
print(dataframe.head(5))
# Out:
#     min  mean   max   t+1
# 0 86.29 86.29 86.29 83.79
# 1 83.79 85.04 86.29 72.15
# 2 72.15 80.74 86.29 67.73
# 3 67.73 77.49 86.29 82.10
# 4 67.73 78.41 86.29 84.01

# %%
refunds_data = refunds_df.copy()
# refunds_data.reset_index(inplace = True)
refunds_data.head()
# Out:
#                   refunds
# transaction_date
# 2016-01-01          86.29
# 2016-01-02          83.79
# 2016-01-03          72.15
# 2016-01-04          67.73
# 2016-01-05          82.10

# %%
refunds_data.drop(pd.to_datetime('2016-02-29'), inplace = True)
refunds_data = refunds_data.iloc[0:1095]
refunds_data.tail()
# Out:
#                   refunds
# transaction_date
# 2018-12-27          45.69
# 2018-12-28          50.65
# 2018-12-29          58.93
# 2018-12-30          55.80
# 2018-12-31          21.38

# %%
# create date and time features

# dataframe = pd.DataFrame()
# dataframe['month'] = [refunds_data.transaction_date[i].month for i in range(len(refunds_data))]
# dataframe['day'] = [refunds_data.transaction_date[i].day for i in range(len(refunds_data))]
# dataframe['refunds'] = [refunds_data.refunds[i] for i in range(len(refunds_data))]
# print(dataframe.head(5))

# %%
# df.squeeze()
# Series or DataFrames with a single element are squeezed to a scalar. 
# DataFrames with a single column or a single row are squeezed to a Series. 

series = refunds_data.squeeze()
series
# Out:
# transaction_date
# 2016-01-01   86.29
# 2016-01-02   83.79
# 2016-01-03   72.15
# 2016-01-04   67.73
# 2016-01-05   82.10
#               ...
# 2018-12-27   45.69
# 2018-12-28   50.65
# 2018-12-29   58.93
# 2018-12-30   55.80
# 2018-12-31   21.38
# Name: refunds, Length: 1095, dtype: float64

# %%
# create yearly (stacked) line plots


groups = series.groupby(pd.Grouper(freq='A'))
years = pd.DataFrame()
for name, group in groups:
    years[name.year] = group.values
years.plot(subplots=True, legend=False,figsize=(15, 10))
plt.show()

# %%
# Create histogram with density plot
import seaborn as sns
sns.distplot(refunds_data.refunds, hist=True, kde=True,
             bins=20,              
             color = 'blue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 2})
# Out:
# <AxesSubplot:xlabel='refunds', ylabel='Density'>

# %%
# create a boxplot of yearly data
years.boxplot(figsize=(15,5))
plt.show()

# %%
# create a monthly boxplots for 2018

single_year = series['2018']
groups = single_year.groupby(pd.Grouper(freq='M'))
months = pd.concat([pd.DataFrame(x[1].values) for x in groups], axis=1)
months = pd.DataFrame(months)
months.columns = range(1,13)
months.boxplot(figsize=(15,5))
plt.show()

# %%
# create a heat map of yearly data

years = years.T
plt.matshow(years, interpolation=None, aspect='auto')
plt.show()

# %%
# create multiple scatter plots
from pandas.plotting import lag_plot

values = pd.DataFrame(series.values)
lags = 3
columns = [values]
for i in range(1,(lags + 1)):
    columns.append(values.shift(i))
dataframe = pd.concat(columns, axis=1)
columns = ['t']
for i in range(1,(lags + 1)):
    columns.append('t-' + str(i))
dataframe.columns = columns
plt.figure(1,figsize=(20,12))
for i in range(1,(lags + 1)):
    ax = plt.subplot(240 + i)
    ax.set_title('t vs t-' + str(i))
    plt.scatter(x=dataframe['t'].values, y=dataframe['t-'+str(i)].values)
plt.show()

# %%
# create an autocorrelation plot
from pandas.plotting import autocorrelation_plot

# take a look at autocorrelation again - doesn't look right for some reasons
autocorrelation_plot(series)
plt.show()

# %%
# downsample to quarterly intervals

resample = series.resample('Q')
quarterly_mean_sales = resample.mean()
print(quarterly_mean_sales.head())
# Out:
# transaction_date
# 2016-03-31   79.28
# 2016-06-30   74.88
# 2016-09-30   72.08
# 2016-12-31   74.13
# 2017-03-31   60.82
# Freq: Q-DEC, Name: refunds, dtype: float64

# %%
#Plot quarterly sampled data
quarterly_mean_sales.plot(figsize=(15,5))
plt.show()

# %% [markdown]
# ### Power Transformation

# %%
# load and plot a time series

plt.figure(1, figsize=(15,6))
# line plot
plt.subplot(211)
plt.plot(series)
# histogram
plt.subplot(212)
plt.hist(series)
plt.show()

# %%
# square root transform a time series

dataframe = pd.DataFrame(series.values)
dataframe.columns = ['refunds']
dataframe['refunds'] = np.sqrt(dataframe['refunds'])
plt.figure(1,figsize=(15,6))
# line plot
plt.subplot(211)
plt.plot(dataframe['refunds'])
# histogram
plt.subplot(212)
plt.hist(dataframe['refunds'])
plt.show()

# %%
# # log transform a time series

refunds_data = refunds_df.copy()
series = refunds_data.squeeze()
dataframe = pd.DataFrame(series.values)
dataframe.columns = ['refunds']
dataframe['refunds'] = np.log(dataframe['refunds'])
plt.figure(1,figsize=(15,6))
# line plot
plt.subplot(211)
plt.plot(dataframe['refunds'])
# histogram
plt.subplot(212)
plt.hist(dataframe['refunds'])
plt.show()

# %% [markdown]
# ### Box-cox Transformation

# %%
# manually box-cox transform a time series
from scipy.stats import boxcox

refunds_data = refunds_df.copy()
series = refunds_data.squeeze()
dataframe = pd.DataFrame(series.values)
dataframe.columns = ['refunds']
dataframe['refunds'] = boxcox(dataframe['refunds'], lmbda=0.0)
plt.figure(1,figsize=(15,6))

# line plot
plt.subplot(211)
plt.plot(dataframe['refunds'])

# histogram
plt.subplot(212)
plt.hist(dataframe['refunds'])
plt.show()

# %%
# automatically box-cox transform a time series

refunds_data = refunds_df.copy()
series = refunds_data.squeeze()
dataframe = pd.DataFrame(series.values)
dataframe.columns = ['refunds']
dataframe['refunds'], lam = boxcox(dataframe['refunds'])
print('Lambda: %f' % lam)
plt.figure(1,figsize=(15,6))
# line plot
plt.subplot(211)
plt.plot(dataframe['refunds'])
# histogram
plt.subplot(212)
plt.hist(dataframe['refunds'])
plt.show()
# Out:
# Lambda: 0.915911

# %% [markdown]
# ### Calculating differences between weekly and yearly averages

# %%
refunds_data = refunds_df.copy()
refunds_data.reset_index(inplace = True)
refunds_data.head()
# Out:
#   transaction_date  refunds
# 0       2016-01-01    86.29
# 1       2016-01-02    83.79
# 2       2016-01-03    72.15
# 3       2016-01-04    67.73
# 4       2016-01-05    82.10

# %%
dataframe = pd.DataFrame()
dataframe['year'] = [refunds_data.transaction_date[i].year for i in range(len(refunds_data))]
dataframe['month'] = [refunds_data.transaction_date[i].month for i in range(len(refunds_data))]
dataframe['day'] = [refunds_data.transaction_date[i].day for i in range(len(refunds_data))]
dataframe['week'] = [refunds_data.transaction_date[i].week for i in range(len(refunds_data))]
dataframe['weekday'] = [refunds_data.transaction_date[i].weekday() for i in range(len(refunds_data))]
dataframe['refunds'] = [refunds_data.refunds[i] for i in range(len(refunds_data))]
print(dataframe.head(5))
# Out:
#    year  month  day  week  weekday  refunds
# 0  2016      1    1    53        4    86.29
# 1  2016      1    2    53        5    83.79
# 2  2016      1    3    53        6    72.15
# 3  2016      1    4     1        0    67.73
# 4  2016      1    5     1        1    82.10

# %%
rows_to_drop = dataframe[dataframe['year']==2019].index
# print(rows_to_drop)
dataframe.drop(rows_to_drop, axis = 0, inplace = True)
# Out:
# Int64Index([1096, 1097, 1098, 1099, 1100, 1101, 1102, 1103, 1104, 1105, 1106,
#             1107, 1108, 1109, 1110, 1111, 1112, 1113, 1114, 1115, 1116, 1117,
#             1118, 1119, 1120, 1121, 1122, 1123, 1124, 1125, 1126, 1127, 1128,
#             1129, 1130, 1131, 1132, 1133, 1134, 1135, 1136, 1137, 1138, 1139,
#             1140, 1141, 1142, 1143, 1144, 1145, 1146, 1147, 1148, 1149, 1150,
#             1151, 1152, 1153, 1154, 1155, 1156, 1157, 1158, 1159, 1160, 1161,
#             1162, 1163, 1164, 1165, 1166, 1167, 1168, 1169, 1170, 1171, 1172,
#             1173, 1174, 1175, 1176, 1177, 1178, 1179, 1180, 1181, 1182, 1183,
#             1184, 1185],
#            dtype='int64')

# %%
yearly_avg = dataframe.groupby(['year'], as_index = True)['refunds'].agg(['mean']).reset_index()
yearly_avg.head()
# Out:
#    year  mean
# 0  2016 75.05
# 1  2017 57.40
# 2  2018 31.56

# %%
weekly_avg = dataframe.groupby(['year','week'], as_index = True)['refunds'].agg(['mean']
                                                                     ).reset_index()
weekly_avg.head()
# Out:
#    year  week  mean
# 0  2016     1 81.07
# 1  2016     2 75.79
# 2  2016     3 73.37
# 3  2016     4 72.26
# 4  2016     5 71.98

# %%
new_data = pd.merge(weekly_avg, yearly_avg, how = "left",on=["year", "year"])
new_data['difference'] = new_data['mean_x'] - new_data['mean_y']
new_data.head()
# Out:
#    year  week  mean_x  mean_y  difference
# 0  2016     1   81.07   75.05        6.02
# 1  2016     2   75.79   75.05        0.74
# 2  2016     3   73.37   75.05       -1.69
# 3  2016     4   72.26   75.05       -2.80
# 4  2016     5   71.98   75.05       -3.08

# %%
# when I substract weekly average from yearly averages, there is no downward trend in the data. The differences 
# look stable 
plt.figure(1,figsize=(15,6))
plt.plot(new_data['difference'])
plt.show()

# %%
plt.figure(1,figsize=(15,6))
plt.plot(weekly_avg['mean'])
plt.show()

# %%
weekday_avg = dataframe.groupby(['year','weekday'], as_index = True)['refunds'].agg(['mean']
                                                                     ).reset_index()
weekday_avg
# Out:
#     year  weekday  mean
# 0   2016        0 66.99
# 1   2016        1 76.09
# 2   2016        2 79.10
# 3   2016        3 78.43
# 4   2016        4 77.44
# 5   2016        5 77.17
# 6   2016        6 70.07
# 7   2017        0 52.11
# 8   2017        1 58.99
# 9   2017        2 59.14
# 10  2017        3 60.17
# 11  2017        4 59.85
# 12  2017        5 58.73
# 13  2017        6 52.88
# 14  2018        0 21.73
# 15  2018        1 29.02
# 16  2018        2 37.74
# 17  2018        3 37.45
# 18  2018        4 38.31
# 19  2018        5 38.19
# 20  2018        6 18.64

# %%
plt.figure(1,figsize=(15,6))
plt.plot(weekday_avg['mean'])
plt.show()
